# %% [markdown]
# <a href="https://colab.research.google.com/github/GTU9/PythonStudy/blob/main/orderCoffee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pickle import NONE
from logging import NullHandler
MENU = {
    "americano": {
        "ingredients": {
            "water": 350,
            "coffee": 20,
        },
        "cost": 2000,
    },
    "latte": {
        "ingredients": {
            "water": 200,
            "milk": 150,
            "coffee": 24,
        },
        "cost": 2500,
    },
    "cappuccino": {
        "ingredients": {
            "water": 250,
            "milk": 100,
            "coffee": 24,
        },
        "cost": 3000,
    }
}

profit = 0

resources = {
    "water": 300,
    "milk": 200,
    "coffee": 100,
}

conti = False
menu=None

def order():
  print()
  print("--------------------------------------------------")
  print("###############커피 주문 프로그램#################")
  print("--------------------------------------------------")
  print("주문 품목은 아메리카노, 라떼,  카푸치노 입니다.")
  order=input("어떤 음료를 드릴까요? (americano/latte/cappuccino): ")
  global menu
  if(order=="americano" or order=="latte" or order=="cappuccino"):
    menu=order
    print()

  if order == "off":
   global conti
   conti = True
   print("커피머신을 종료합니다.")
  elif order == "report":
    print(f"물:{resources['water']}ml")
    print(f"우s유:{resources['milk']}ml")
    print(f"원두:{resources['coffee']}g")
    print(f"현금:{profit}원")



def checkResource(menu):
  for key in resources:
    if(key not in MENU[menu]["ingredients"]):
      print(end="")
    else:
     if(resources[key]<MENU[menu]["ingredients"][key]):
       print("현재 "+key+ "재료가 부족하여 만들 수 없습니다. 죄송합니다.")
       print()
       order()

def insertMoney():
  print("현금을 투입하세요.")
  p10000=int(input("만원 지폐: "))
  p5000=int(input("오천원 지폐: "))
  p1000=int(input("천원 지폐: "))
  money=p10000*10000+p5000*5000+p1000*1000
  print("투입한 현금은 총",money ,"원 입니다.")

  return money

def checkMoney(money, menu):
  print()
  global profit
  if(money<MENU[menu]["cost"]):
    print("투입하신 현금이 부족합니다. 투입한",money,"원은 다시 돌려드립니다.")
  elif(money>MENU[menu]["cost"]):
    print("투입하신 현금은",money,"원 이며, 선택하신 메뉴 "+menu+" 의 가격은",MENU[menu]["cost"],"원 입니다. 잔돈",money-MENU[menu]["cost"],"원을 반환합니다.")
    profit=profit+MENU[menu]["cost"]
    print()
    print("커피를 제조중입니다.")
  else:
    print("투입하신 현금은",money,"원 이며, 선택하신 메뉴"+menu+"의 가격은",MENU[menu]["cost"],"원 입니다.")
    profit=profit+MENU[menu]["cost"]
    print()
    print("커피를 제조중입니다.....")
1
def resultCoffee(Menu):
  print()
  print("주문하신 "+Menu+" 가 나왔습니다. 즐거운 하루 보내세요!")
  global menu
  menu=None
  print()

while not conti:
  order()
  if(menu!=None):
   checkResource(menu)
   checkMoney(insertMoney(),menu)
   resultCoffee(menu)
# Out:
# --------------------------------------------------
# ###############커피 주문 프로그램#################
# --------------------------------------------------
# 주문 품목은 아메리카노, 라떼,  카푸치노 입니다.
# 어떤 음료를 드릴까요? (americano/latte/cappuccino): americano
#
# 현재 water재료가 부족하여 만들 수 없습니다. 죄송합니다.
#
#
# --------------------------------------------------
# ###############커피 주문 프로그램#################
# --------------------------------------------------
# 주문 품목은 아메리카노, 라떼,  카푸치노 입니다.
# 어떤 음료를 드릴까요? (americano/latte/cappuccino): latte
#
# 현금을 투입하세요.
# 만원 지폐: 1
# 오천원 지폐: 2
# 천원 지폐: 2
# 투입한 현금은 총 22000 원 입니다.
#
# 투입하신 현금은 22000 원 이며, 선택하신 메뉴 latte 의 가격은 2500 원 입니다. 잔돈 19500 원을 반환합니다.
#
# 커피를 제조중입니다.
#
# 주문하신 latte 가 나왔습니다. 즐거운 하루 보내세요!
#
#
# --------------------------------------------------
# ###############커피 주문 프로그램#################
# --------------------------------------------------
# 주문 품목은 아메리카노, 라떼,  카푸치노 입니다.
# 어떤 음료를 드릴까요? (americano/latte/cappuccino): report
# 물:300ml
# 우s유:200ml
# 원두:100g
# 현금:2500원
#
# ...
